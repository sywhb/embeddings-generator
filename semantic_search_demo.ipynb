# %% [markdown]
# # DEMO: semantic search by using vector embeddings

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
# Install dependencies.
# !pip install asyncpg
# !pip install numpy pandas
# !pip install pgvector
# !pip install langchain transformers sentence_transformers
# !pip install Elasticsearch==7.17.9
# !pip install markdownify
# !pip install sklearn
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: asyncpg in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (0.27.0)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: numpy in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (1.22.4)
# Requirement already satisfied: pandas in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: pgvector in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (0.1.8)
# Requirement already satisfied: numpy in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pgvector) (1.22.4)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: langchain in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (0.0.196)
# Requirement already satisfied: transformers in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (4.30.1)
# Requirement already satisfied: sentence_transformers in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: PyYAML>=5.4.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from langchain) (2.0.19)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from langchain) (3.8.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from langchain) (4.0.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from langchain) (0.5.14)
# Requirement already satisfied: langchainplus-sdk>=0.0.7 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from langchain) (0.0.20)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from langchain) (2.8.4)
# Requirement already satisfied: numpy<2,>=1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from langchain) (1.22.4)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from langchain) (1.2.4)
# Requirement already satisfied: pydantic<2,>=1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from langchain) (1.10.12)
# Requirement already satisfied: requests<3,>=2 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from langchain) (2.28.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: filelock in /Users/hongbowu/.local/lib/python3.10/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from transformers) (0.16.4)
# Requirement already satisfied: packaging>=20.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from transformers) (23.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from sentence_transformers) (2.0.1)
# Requirement already satisfied: torchvision in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from sentence_transformers) (0.15.2)
# Requirement already satisfied: scikit-learn in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from sentence_transformers) (1.2.1)
# Requirement already satisfied: scipy in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from sentence_transformers) (1.10.0)
# Requirement already satisfied: nltk in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from sentence_transformers) (3.7)
# Requirement already satisfied: sentencepiece in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: attrs>=17.3.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: fsspec in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests<3,>=2->langchain) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2022.12.7)
# Requirement already satisfied: sympy in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: click in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from nltk->sentence_transformers) (8.1.3)
# Requirement already satisfied: joblib in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from torchvision->sentence_transformers) (9.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (0.4.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: Elasticsearch==7.17.9 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (7.17.9)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from Elasticsearch==7.17.9) (1.26.14)
# Requirement already satisfied: certifi in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from Elasticsearch==7.17.9) (2022.12.7)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: markdownify in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (0.11.6)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from markdownify) (4.11.2)
# Requirement already satisfied: six<2,>=1.15 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from markdownify) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from beautifulsoup4<5,>=4.9->markdownify) (2.3.2.post1)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting sklearn
#   Downloading sklearn-0.0.post7.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#
#       If the previous advice does not cover your use case, feel free to report it at
#       https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# Automatically restart kernel after installs so that your environment
# can access the new packages.
import IPython

app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
from elasticsearch import Elasticsearch
from elasticsearch.helpers import scan as escan
import pandas as pd
from collections import deque

# Elasticsearch configuration
host = os.environ.get("ELASTICSEARCH_HOST")
username = os.environ.get("ELASTICSEARCH_USERNAME")
password = os.environ.get("ELASTICSEARCH_PASSWORD")
es = Elasticsearch([host], http_auth=(username, password))
index = 'pages_alias'


query = {
  "query": {
    "bool": {
      "must": [
        {
          "range": {
            "savedAt": {
              "gte": "now-7d/d",
              "lte": "now/d",
              "format": "yyyy-MM-dd"
            }
          }
        },
        {
          "term": {
            "userId": {
              "value": os.environ.get("USER_ID")
            }
          }
        },
        {
          "exists": {
            "field": "rssFeedUrl"
          }
        }
      ]
    }
  },
  "_source": {
    "includes": [
      "id",
      "title",
      "author",
      "description",
      "content",
      "readingProgressPercent"
    ]
  },
  "sort": [
    {
      "savedAt": {
        "order": "desc"
      }
    }
  ]
}
# Scan API for larger library
response = escan(client=es, index=index, query=query, request_timeout=30, size=100)

# Initialize a double ended queue
output = deque()
# Extend deque with iterator
output.extend(response)
# Convert deque to DataFrame
# df = json_normalize(output)
# df = df[[x for x in df.columns if "_source." in x]]

# Search API
# search_result = es.search(index=index, body=query)
# hits = search_result["hits"]["hits"]
results = []
for hit in output:
    source = hit["_source"]
    source["id"] = hit["_id"]
    source["progress"] = source["readingProgressPercent"]
    # description could be null
    if 'description' not in source or source['description'] is None:
        source['description'] = ''
    # author could be null
    if 'author' not in source or source['author'] is None:
        source['author'] = ''
    results.append(source)
    
df = pd.DataFrame.from_records(results, exclude=['readingProgressPercent'])
df.head()
# Out:
#            author                                        description  \
# 0  Deutsche Welle  The French embassy has said evacuation plans a...
# 1       The Count  The new graphics card range will also come wit...
# 2                  Unto all who come by these present letters, gr...
# 3       Lee Moran  The former president has said he'll skip the F...
# 4       Lee Moran  The flashing sign may be gone, but won’t be fo...
#
#                      id                                              title  \
# 0  lCdUsIkBwAZ9NKfgk1OK  Niger coup: France prepares evacuations – DW –...
# 1  hflVsIkBfarSEDd1lMo-  Gigabyte debuts new Aorus Elite graphics cards...
# 2  kidUsIkBwAZ9NKfge1PF                              From their Highnesses
# 3  h_lVsIkBfarSEDd1ycoY  Trump Taunts GOP Rivals Over Debate With Vice ...
# 4  nydVsIkBwAZ9NKfg0lN5  Elon Musk Ridiculed For Short Lived X Sign | H...
#
#                                              content  progress
# 0  <div class="page" id="readability-page-1"><div...       0.0
# 1  <div class="page" id="readability-page-1"><div...       0.0
# 2  <div class="page" id="readability-page-1"><div...       0.0
# 3  <div class="page" id="readability-page-1"><div...       0.0
# 4  <div class="page" id="readability-page-1"><fig...       0.0

# %%
# Save the Pandas dataframe in a PostgreSQL table.
import asyncpg


async def main():
    # Create connection to SQL database
    conn = await asyncpg.connect(database='test')

    await conn.execute("DROP TABLE IF EXISTS test CASCADE")
    # Create the `test` table.
    await conn.execute(
        """CREATE TABLE test(
                    id VARCHAR(1024) PRIMARY KEY,
                    title TEXT,
                    author TEXT,
                    description TEXT,
                    progress NUMERIC,
                    content TEXT)"""
    )

    # Copy the dataframe to the `test` table.
    tuples = list(df.itertuples(index=False))
    await conn.copy_records_to_table(
        "test", records=tuples, columns=list(df), timeout=10
    )
    await conn.close()


# Run the SQL commands now.
await main()  # type: ignore

# %%
# convert html to markdown

from markdownify import markdownify as md

def html_to_markdown(html):
    return md(html)

# %% [markdown]
# Vector Embeddings

# %%
# Split long text descriptions into smaller chunks that can fit into
# the API request size limit, as expected by the LLM providers.

from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    separators=[".", "\n"],
    chunk_size=500,
    chunk_overlap=0,
    length_function=len,
)
chunked = []
for index, row in df.iterrows():
    id = row["id"]
    title = row["title"]
    description = row["description"]
    author = row["author"]
    # content = html_to_markdown(row["content"])
    splits = text_splitter.create_documents([title])
    for s in splits:
        r = {"id": id, "content": s.page_content}
        chunked.append(r)

# %% [markdown]
# Step 2: Generate vector embedding for each chunk by calling an Embedding Generation service

# %%
# Generate the vector embeddings for each chunk of text.
# This code snippet may run for a few minutes.

from langchain.embeddings import HuggingFaceEmbeddings

model_name = "sentence-transformers/paraphrase-multilingual-mpnet-base-v2"
model_kwargs = {'device': 'cpu'}
encode_kwargs = {'normalize_embeddings': True}
embeddings_service = HuggingFaceEmbeddings( 
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

batch_size = 5
for i in range(0, len(chunked), batch_size):
    documents = [x["content"] for x in chunked[i : i + batch_size]]
    embedding = embeddings_service.embed_documents(documents)
    # Store the retrieved vector embeddings for each chunk back.
    for x, e in zip(chunked[i : i + batch_size], embedding):
        x["embedding"] = e

# Store the generated embeddings in a pandas dataframe.
embeddings = pd.DataFrame(chunked)
embeddings.head()
# Out:
#                      id                                            content  \
# 0  lCdUsIkBwAZ9NKfgk1OK  Niger coup: France prepares evacuations – DW –...
# 1  hflVsIkBfarSEDd1lMo-  Gigabyte debuts new Aorus Elite graphics cards...
# 2  kidUsIkBwAZ9NKfge1PF                              From their Highnesses
# 3  h_lVsIkBfarSEDd1ycoY  Trump Taunts GOP Rivals Over Debate With Vice ...
# 4  nydVsIkBwAZ9NKfg0lN5  Elon Musk Ridiculed For Short Lived X Sign | H...
#
#                                            embedding
# 0  [0.02600826881825924, 0.015473218634724617, -0...
# 1  [-0.003796227276325226, -0.028414282947778702,...
# 2  [0.041707273572683334, 0.03731207549571991, -0...
# 3  [0.011007378809154034, 0.03349965810775757, -0...
# 4  [0.040546514093875885, -0.017225362360477448, ...

# %%
# get token

# %%
from sklearn.cluster import KMeans
from sentence_transformers import util
import torch

# Perform kmean clustering
# num_clusters = 5
# clustering_model = KMeans(n_clusters=num_clusters)
# clustering_model.fit(embeddings['embedding'].to_list())
# cluster_assignment = clustering_model.labels_

# clustered_sentences = [[] for i in range(num_clusters)]
# for sentence_id, cluster_id in enumerate(cluster_assignment):
#     clustered_sentences[cluster_id].append(embeddings['content'][sentence_id])

# for i, cluster in enumerate(clustered_sentences):
#     print("Cluster ", i+1)
#     print(cluster)
#     print("")
    
#Two parameters to tune:
#min_cluster_size: Only consider cluster that have at least 25 elements
#threshold: Consider sentence pairs with a cosine-similarity larger than threshold as similar
# creating tensor from embeddings 
torch_tensor = torch.tensor(embeddings['embedding'])

clusters = util.community_detection(torch_tensor, min_community_size=10, threshold=0.5)

#Print for all clusters the top 3 and bottom 3 elements
for i, cluster in enumerate(clusters):
    print("\nCluster {}, #{} Elements ".format(i+1, len(cluster)))
    for sentence_id in cluster[0:3]:
        print("\t", embeddings['content'][sentence_id])
    print("\t", "...")
    for sentence_id in cluster[-3:]:
        print("\t", embeddings['content'][sentence_id])
# Out:
# Cluster 1, #82 Elements
# 	 https://news.google.?oc=5
# 	 https://news.google.com/rss/articles/CBMingFodHRwczovL2dhbWVpc2hhcmQuZ2cvbmV3cy9vbmUtb2YtdGhlLWJlc3Qtc3RlYWx0aC1ob3Jyb3ItZ2FtZXMtYXJvdW5kLWhhcy1wYXNzZWQtdGhhdC1lYXJseS1hY2Nlc3MtdGhyZXNob2xkLWl0cy1kZWZpbml0ZWx5LXRpbWUtdG8tY2hlY2stb3V0LWdsb29td29vZC82OTg2L9IBAA?oc=5
# 	 https://www.politico.com/news/2023/08/01/maternal-health-care-crisis-00109106
# 	 ...
# 	 Here's What Happened Today: Monday · TheJournal.ie
# 	 The 8 at 8: Tuesday · TheJournal.ie
# 	 https://news.google.com/rss/articles/CBMiUmh0dHBzOi8vd3d3LmdhbWVzaHViLmNvbS9uZXdzL25ld3MvYWN0aXZpc2lvbi1ibGl6emFyZC1tZXJnZXItbmV3LXplYWxhbmQtMjYyNTkzMi_SAQA?oc=5
#
# Cluster 2, #48 Elements
# 	 Trump federally indicted in 2020 election probe – DW – 08/01/2023
# 	 Donald Trump indicted over attempts to overturn 2020 election
# 	 Trump indicted for bid to overturn 2020 election result - POLITICO
# 	 ...
# 	 Ex-Biden Chief Of Staff Names ‘Scariest Thing’ About Trump Indictment | HuffPost Latest News
# 	 CNN Host Laughs Out Loud At Trump Attorney's Revisionist History | HuffPost Latest News
# 	 Nancy Pelosi Calls Trump Indictments 'Beautiful And Intricate' | HuffPost Latest News
#
# Cluster 3, #27 Elements
# 	 Niger coup: France prepares evacuations – DW – 08/01/2023
# 	 Niger coup: Burkina Faso, Mali warn against intervention – DW – 08/01/2023
# 	 ECOWAS threatens 'use of force' against Niger junta – DW – 07/31/2023
# 	 ...
# 	 Niger closes airspace over 'threat of intervention' as junta defies ECOWAS deadline
# 	 Niger: A German foreign policy miscalculation? – DW – 08/07/2023
# 	 Niger coup leaders refuse to let senior U.S. diplomat meet with deposed president - POLITICO
#
# Cluster 4, #24 Elements
# 	 Exciting Games Coming to Game Pass in September
# 	 A new Samba de Amigo game is coming to Apple Arcade - The Verge
# 	 Battle Shapers Preview - YouTube
# 	 ...
# 	 Gran Turismo 7 - August 1.36 Update | PS5 & PS VR2 - YouTube
# 	 Call of Duty: Modern Warfare III Official Teaser Trailer - YouTube
# 	 Persona 5: The Phantom X - Closed Beta Test #2 Trailer - YouTube
#
# Cluster 5, #23 Elements
# 	 Ukraine updates: Moscow says drone hit finance center tower – DW – 08/01/2023
# 	 End of the line for Russia and Ukraine’s partnership in rocketry | Ars Technica
# 	 Ukraine’s plan if Russia assassinates Zelenskyy – POLITICO
# 	 ...
# 	 Ukraine updates: Kyiv claims Crimea bridge strike – DW – 08/07/2023
# 	 Ukraine updates: Russia strikes Pokrovsk homes, Kyiv says – DW – 08/07/2023
# 	 Five dead and 31 injured as Russian missile strikes hit eastern Ukrainian city centre
#
# Cluster 6, #19 Elements
# 	 Neues von unserem Facebook | Die Baronie Knight's Crossing - SCA in Deutschland
# 	 Mane to Al Nassr: Where did it go wrong at Bayern Munich? – DW – 08/01/2023
# 	 Germany: Once again the 'sick man' of Europe? – DW – 08/01/2023
# 	 ...
# 	 German AfD: Revival of far-right a 'threat to Jewish life' – DW – 08/05/2023
# 	 Germany's far-right AfD derides EU as 'failed project' – DW – 08/06/2023
# 	 Upcoming Activities | Die Baronie Knight's Crossing - SCA in Deutschland
#
# Cluster 7, #18 Elements
# 	 https://www.politico.com/minutes/congress/08-1-2023/baldwin-tiffany-gop-senate-wisconsin/
# 	 Revealed: The criteria for the second Republican presidential primary debate - POLITICO
# 	 'I Want Justice': Capitol Officers React To Trump Indictment | HuffPost Latest News
# 	 ...
# 	 Larry Donnelly: This Trump indictment is explosive - it makes for chilling reading
# 	 Navalny's latest conviction 'purely political,' allies say – DW – 08/04/2023
# 	 Trump: Pence has ‘gone to the Dark Side’ - POLITICO
#
# Cluster 8, #12 Elements
# 	 Trump Taunts GOP Rivals Over Debate With Vice President Jab | HuffPost Latest News
# Cluster 14, #10 Elements
# 	 OneXFly: A New Competitor to the Steam Deck and ROG Ally in the Handheld Gaming Market
# 	 SteamDB entry appears for Fantasian | RPG Site
# 	 Everyone's Downloading Baldur's Gate 3 and Steam Is Having a Wobble - IGN
# 	 ...
# 	 Baldur's Gate 3 Players Is Shocking Players With Full Frontal Nudity - IGN Daily Fix - YouTube
# 	 Baldur’s Gate 3 Reactions: A Game Changing Feature
# 	 'It's gotten more popular every day': Asmongold reacts to Baldur's Gate 3 reaching over 700,000 active players on Steam
#
# Cluster 15, #10 Elements
# 	 The Dark Side of Being a Child Prodigy | HuffPost HuffPost Personal
# 	 https://www.huffpost.com/entry/blake-lively-baby-daddy-joke_n_64c936b8e4b044bf98f7bfd9
# 	 What It’s Like Caring For A Parent Dying Of Cancer | HuffPost HuffPost Personal
# 	 ...
# 	 Uncover The Hidden Power Of An Unassuming Pedestal Fan | HuffPost Life
# 	 Echosmith's 'Cool Kids' Led Me To Surprising Places | HuffPost HuffPost Personal
# 	 O'Shae Sibley And The Joy Of Boys Like Him | HuffPost Voices

# %% [markdown]
# ### Use pgvector to store the generated embeddings within PostgreSQL
#
# - The `pgvector` extension introduces a new `vector` data type.
# - **The new `vector` data type allows you to directly save a vector embedding (represented as a NumPy array) through a simple INSERT statement in PostgreSQL!**
#
# >⚠️ The following code snippet may run for a few minutes.

# %%
# Store the generated vector embeddings in a PostgreSQL table.
# This code may run for a few minutes.

import numpy as np
from pgvector.asyncpg import register_vector


async def main():
    # Create connection to SQL database.
    conn = await asyncpg.connect(database='test')

    await conn.execute("CREATE EXTENSION IF NOT EXISTS vector")
    await register_vector(conn)

    await conn.execute("DROP TABLE IF EXISTS test_embeddings")
    # Create the `test_embeddings` table to store vector embeddings.
    await conn.execute(
        """CREATE TABLE test_embeddings(
                            test_id VARCHAR(1024) NOT NULL REFERENCES test(id),
                            content TEXT,
                            embedding vector(768))"""
    )

    # Store all the generated embeddings back into the database.
    for index, row in embeddings.iterrows():
        await conn.execute(
            "INSERT INTO test_embeddings (test_id, content, embedding) VALUES ($1, $2, $3)",
            row["id"],
            row["content"],
            np.array(row["embedding"]),
        )

    await conn.close()


# Run the SQL commands now.
await main()  # type: ignore

# %% [markdown]
# Step 1: Generate the vector embedding for the user query

# %%
user_query = 'sports'
min_progress = 0  # @param {type:"integer"}
max_progress= 100  # @param {type:"integer"}

qe = embeddings_service.embed_query(user_query)
qe
# Out:
# [-0.07225033640861511,
#  -0.0016877002781257033,
#  -0.00423727510496974,
#  0.07335066795349121,
#  0.0025142382364720106,
#  -0.04136274382472038,
#  -0.044574253261089325,
#  0.03261534497141838,
#  0.0007996244239620864,
#  -0.024010641500353813,
#  0.07381800562143326,
#  -0.003088634228333831,
#  -0.0035691699013113976,
#  0.04320652782917023,
#  0.04156501591205597,
#  -0.013221917673945427,
#  -0.053041424602270126,
#  -0.021313371136784554,
#  -0.017885055392980576,
#  0.00309254159219563,
#  -0.015640603378415108,
#  0.0007444623042829335,
#  -0.001701891073025763,
#  -0.01781659573316574,
#  -0.040776144713163376,
#  -0.07028353214263916,
#  -0.03225020319223404,
#  0.010331757366657257,
#  -0.04571333900094032,
#  0.012426995672285557,
#  0.004417872056365013,
#  -0.039477720856666565,
#  -0.03265779837965965,
#  -0.02072547934949398,
#  0.01302234549075365,
#  0.03843856230378151,
#  0.0145106827840209,
#  0.08634602278470993,
#  -0.0590810663998127]

# %% [markdown]
# Step 2: Use `pgvector` to find similar items
#
#
# - The new `pgvector` similarity search operators provide powerful semantics
# to combine the vector search operation with regular query filters in a single SQL query.
# - **Using pgvector, you can now seamlessly integrate the power of relational databases with your vector search operations!**

# %%
from pgvector.asyncpg import register_vector
import asyncpg
from IPython.display import display, HTML

matches = []


async def main():
    # Create connection to SQL database.
    conn = await asyncpg.connect(database='test')

    await register_vector(conn)
    similarity_threshold = 0.3
    num_matches = 5

    # Find similar items to the query using cosine similarity search
    # over all vector embeddings. This new feature is provided by `pgvector`.
    results = await conn.fetch(
        """
                        WITH vector_matches AS (
                          SELECT test_id, 1 - (embedding <=> $1) AS similarity
                          FROM test_embeddings
                          WHERE 1 - (embedding <=> $1) > $2
                          ORDER BY similarity DESC
                          LIMIT $3
                        )
                        SELECT title, author, description, progress, content FROM test
                        WHERE id IN (SELECT test_id FROM vector_matches)
                        AND progress >= $4 AND progress <= $5
                        """,
        qe,
        similarity_threshold,
        num_matches,
        min_progress,
        max_progress
    )

    if len(results) == 0:
        raise Exception("Did not find any results. Adjust the query parameters.")

    for r in results:
        # Collect the description for all the matched similar items
        matches.append(
            f"""Title: {r["title"]}.
                Author: {r["author"]}.
                Description: {r["description"]}.
                Reading progress: {round(r['progress'])}.
                Content: {display(HTML(r["content"]))}."""
        )
        
    await conn.close()


# Run the SQL commands now.
await main()  # type: ignore

# Show the results for similar products that matched the user query.
matches
# Out:
# <DIV class="page" id="readability-page-1"><DIV>
# <td>
# <!--[if mso]>
# <table style="width:600px;"><tr><td>
# <![endif]-->
# <div>
#
#
#
#
#
#
#
# <tr>
# <td>
# <p>👋 <strong>Good morning!</strong> Another epic sports weekend in the books. Let's do it again in five days.</p><p>⛳️ <strong>Coming soon:</strong> Professional golf is in a state of upheaval, with the Saudi-backed LIV series teeing off this week. Special edition coming soon. We'll explain everything.</p><p><em>Today's word count: 1,635 words (6 minutes).</em></p><p><em>Let's sports...</em></p>
# </td>
# </tr>
# <tr>
# <td>&nbsp;</td>
# </tr>
# <tr>
# <td>&nbsp;</td>
# </tr>
# <tr>
# <td>
# <span>
# 1 big thing: 👑 Nadal is still king
# </span>
# </td>
# </tr>
# <tr>
# <td>
# <p><img alt="" src="https://proxy-prod.omnivore-image-cache.app/0x0,s2Mi4CTLBnxUcvNXrYjK0FMWMdNmAj8ZFDxq61gLGgZY/https://images.axios.com/g6eNDLiEnDD_6Mx7JAZ6QidDo9I=/fit-in/1116x1300/2022/06/05/1654446839016.jpg" width="100%"></p> <p>Photo: STF/AFP via Getty Images</p><p><strong>Rafael Nadal</strong> <a href="https://link.axios.com/click/27959735.225379/aHR0cHM6Ly93d3cueW91dHViZS5jb20vd2F0Y2g_dj1ON0VJNnFUW
aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3NoYXJlci5waHA_"></a>
# <a href="https://link.axios.com/click/27959735.225379/aHR0cHM6Ly90d2l0dGVyLmNvbS9pbnRlbnQvdHdlZXQ_..."></a>
# <a href="https://link.axios.com/click/27959735...."></a>
# <a href="mailto:?subject=From%20Axios:%201%20big%20thing:%20%F0%9F%91%91%20Nadal%20is%20still%20king&body=hongbow-s8n3htsxe%40inbox.omnivore.app%20has%20shared%20an%20Axios%20story%20with%20you%3A%0A%0A1%20big%20thing:%20%F0%9F%91%91%20Nadal%20is%20still%20king%0Ahttps%3A%2F%2Fwww.axios.com%2Fnewsletters%2Faxios-sports-673792f4-a122-4455-90ac-bc6f695581df.html%3Fchunk%3D0%26utm_term%3Demshare#story0"></a>
# </td>
# </tr>
# <tr>
# <td>&nbsp;</td>
# </tr>
# <tr>
# <td>&nbsp;</td>
# </tr>
# <tr>
# <td>
# <span>
# Bonus: 🤯 Mind-blowing dominance
# </span>
# </td>
# </tr>
# <tr>
# <td>
# <!--[if mso]><img alt='' src='https://graphics.axios.com/2022-01-31-grand-slam/fallbacks/2022-01-31-grand-slam-fallback.png' style='max-width: 100%;' width='558' /><![endif]--><!--[if !mso]><!--><img alt="" src="https://proxy-prod.omnivore-image-cache.app/0x0,s8Z9qhwWwjCXvRt-0xPzOHqMs4hf0nZO9O2AkMiY7ymw/https://graphics.axios.com/2022-01-31-grand-slam/fallbacks/2022-01-31-grand-slam-fallback.png" width="100%"><!--<![endif]--><p>Table: Axios Visuals</p><p><strong>This chart will never not blow my mind.</strong> The Big Three have won 62 of the last 75 Grand Slams, and 19 of the last 21.</p><p><strong>Looking ahead:</strong> Who will end up with the most major singles titles?</p><ul><li><strong>Serena Williams,</strong> age 40 <em>(23 titles)</em></li><li><strong>Rafael Nadal,</strong> age 36 <em>(22 titles)</em></li><li><strong>Novak Djokovic,</strong> age 35 <em>(20 titles)</em></li><li><strong>Roger Federer,</strong> age 40 <em>(20 titles)</em></li></ul>
# </td>
# </tr>
# <tr>
# <td>
# <a href="https://link.axios.com/click/27959735.225379/aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3NoYXJlci5waHA_"></a>
# <a href="https://link.axios.com/click/27959735.225379/aHR0cHM6Ly90d2l0dGVyLmNvbS9pbnRlbnQvdHdlZXQ_dGV4dD1Cb251czolMjAlRjAlOUYlQTQlQUYlMjBNaW5kLWJsb3dpbmclMjBkb21pbmFuY2UmaGFzaHRhZ3M9YXhpb3NzcG9ydHMmdXJsPWh0dHBzOi8vd3d3LmF4aW9zLmNvbS9uZXdzbGV0dGVycy9heGlvcy1zcG9ydHMtNjczNzkyZjQtYTEyMi00NDU1LTkwYWMtYmM2ZjY5NTU4MWRmLmh0bWw_Y2h1bmslM0QxJTI2dXRtX3Rlcm0lM0R0d3NvY2lhbHNoYXJlJTIzc3RvcnkxJnV0bV9zb3VyY2U9bmV3c2xldHRlci
# <DIV id="readability-content"><DIV class="page" id="readability-page-1"><DIV data-omnivore-anchor-idx="1">
# <td data-omnivore-anchor-idx="2">
# <!--[if mso]>
# <table style="width:600px;"><tr><td>
# <![endif]-->
# <div data-omnivore-anchor-idx="3">
#
#
#
#
#
#
#
# <tr data-omnivore-anchor-idx="4">
# <td data-omnivore-anchor-idx="5">
# <p data-omnivore-anchor-idx="6">👋 <strong data-omnivore-anchor-idx="7">Good morning!</strong> Welcome back.</p><p data-omnivore-anchor-idx="8"><em data-omnivore-anchor-idx="9">Today's word count: 2,174 words (8 minutes).</em></p><p data-omnivore-anchor-idx="10"><em data-omnivore-anchor-idx="11">Let's sports...</em></p>
# </td>
# </tr>
# <tr data-omnivore-anchor-idx="12">
# <td data-omnivore-anchor-idx="13">&nbsp;</td>
# </tr>
# <tr data-omnivore-anchor-idx="14">
# <td data-omnivore-anchor-idx="15">&nbsp;</td>
# </tr>
# <tr data-omnivore-anchor-idx="16">
# <td data-omnivore-anchor-idx="17">
# <span data-omnivore-anchor-idx="18">
# 1 big thing ... 🔥 Exclusive: New-look Major League Pickleball
# </span>
# </td>
# </tr>
# <tr data-omnivore-anchor-idx="19">
# <td data-omnivore-anchor-idx="20">
# <img data-omnivore-anchor-idx="21" src="https://proxy-prod.omnivore-image-cache.app/600x0,sNtBQkQDrbcrKFMQDCGWEXTFrUrM5MFHy6zkFQtqM8Cc/https://images.axios.com/nlYZm2P76OgEk-MEHcg9Lkwrnkg=/0x0:1920x1080/1920x1080/2022/12/11/1670785153484.jpg" width="600" id="item00" alt="Illustration of a pickleball paddle hitting an exploding ball">
# </td>
# </tr>
# <tr data-omnivore-anchor-idx="22">
# <td data-omnivore-anchor-idx="23"></td>
# </tr>
# <tr data-omnivore-anchor-idx="24">
# <td data-omnivore-anchor-idx="25">
# <span data-omnivore-anchor-idx="26">
# <p data-omnivore-anchor-idx="27">Illustration: Annelise Capossela/Axios</p>
# </span>
# </td>
# </tr>
# <tr data-omnivore-anchor-idx="28">
# <td data-omnivore-anchor-idx="29">&nbsp;</td>
# </tr>
# <tr data-omnivore-anchor-idx="30">
# <td data-omnivore-anchor-idx="31">
# <p data-omnivore-anchor-idx="32"><strong data-omnivore-anchor-idx="33">As pickleball continues to surge in popularity,</strong> <a data-omnivore-anchor-idx="34" href="https://link.axios.com/click/29955481.202452/aHR0cHM6Ly93d3cubWFqb3JsZWFndWVwaWNrbGViYWxsLm5ldC8_dXRtX3NvdXJjZT1uZXdzbGV0dGVyJnV0bV9tZWRpdW09ZW1haWwmdXRtX2NhbXBhaWduPW5ld3NsZXR0ZXJfYXhpb3NzcG9ydHMmc3RyZWFtPXRvcA/624d3914230d0217f00e46a0Bdc4f4ca5" target="_blank">Major League Pickleball</a> — the buzzy pro circuit that counts LeBron James, Tom Brady and Kevin Durant among its team owners — is gearing up to make a splash.</p><p data-omnivore-anchor-idx="35"><strong data-omnivore-anchor-idx="36">Driving the news:</strong> MLP has finalized the format and schedule for 2023, which will see the league double its number of teams (12 to 24) and events (three to six), while ushering in promotion and relegation, Axios has learned.</p><ul data-omnivore-anchor-idx="37"><li data-omnivore-anchor-idx="38"><strong data-omnivore-anchor-idx="39">MLP will announce</strong> today that Brian Levine, a former Goldman Sachs partner and top senior pickleball player, has been hired to serve as interim CEO and lead the search for a permanent CEO and exec team.</li><li data-omnivore-anchor-idx="40"><strong data-omnivore-anchor-idx="41">Just two years after</strong> being founded by billionaire hedge fund manager Steve Kuhn, MLP will offer up to $5 million in prize money and payouts to its players in 2023, Levine tells me.</li></ul><p data-omnivore-anchor-idx="42"><strong data-omnivore-anchor-idx="43">The intrigue:</strong> MLP will implement a promotion and relegation system in 2024, with 12 teams in the Premier Level and 12 teams in the Challenger Level. The 2023 results will determine where each team starts in 2024.</p><p data-omnivore-anchor-idx="44"><strong data-omnivore-anchor-idx="45">How it works:</strong> The 2023 campaign will be divided into two "seasons," each with three events. Prior to each "season," teams will draft their rosters, which consist of two men and two women.</p><ul data-omnivore-anchor-idx="46"><li data-omnivore-anchor-idx="47"><strong data-omnivore-anchor-idx="48">In "Season One,"</strong> 12 teams will compete in the Premier Level (the first 48 drafted players) and 12 will compete in the Challenger Level (the next 48 drafted players). Teams will then flip levels and re-draft.</li><li data-omnivore-anchor-idx="49"><strong data-omnivore-anchor-idx="50">The 12 best teams from 2023</strong> (across both "seasons" and levels) will start in the Premier Level in 2024 and the other 12 will start in the Challenger Level.</li></ul><p data-omnivore-anchor-idx="51"><img data-omnivore-anchor-idx="52" alt="" src="https://proxy-prod.omnivore-image-cache.app/0x0,sxqdrLcl_JVmLVGiloWDoFqqSK88AQtOOLQGiqZU6IDI/https://images.axios.com/N8lfJJNWR34s4xlHO2RpG7R5qVA=/fit-in/1116x1300/2022/12/12/1670844368386.jpg" width="100%"></p> <p data-omnivore-anchor-idx="53">Team BLQK after winning the 2022 MLP finals match in Columbus, Ohio, in October. Photo:  Emilee Chinn/Getty Images</p><p data-omnivore-anchor-idx="54"><strong data-omnivore-anchor-idx="55">2023 schedule:</strong> MLP's six stops in 2023 will feature both Premier and Challenger matches. Life Time, a health club chain, will host each season's championship at their Orange County <a data-omnivore-anchor-idx="56" href="https://link.axios.com/click/29955481...." target="_blank">pickleball facility</a>.</p><ul data-omnivore-anchor-idx="57"><li data-omnivore-anchor-idx="58"><strong data-omnivore-anchor-idx="59">Jan. 26–29:</strong> <a data-omnivore-anchor-idx="60" href="https://link.axios.com/click/29955481.202452/aHR0cHM6Ly9sZWdhY3lzcG9ydHN1c2EuY29tLz91dG1fc291cmNlPW5ld3NsZXR0ZXImdXRtX21lZGl1bT1lbWFpbCZ1dG1fY2FtcGFpZ249bmV3c2xldHRlcl9heGlvc3Nwb3J0cyZzdHJlYW09dG9w/624d3914230d0217f00e46a0B20191ce1" target="_blank">Legacy Sports USA</a> (Mesa, Arizona)</li><li data-omnivore-anchor-idx="61"><strong data-omnivore-anchor-idx="62">March 23 ...
# <div class="page" id="readability-page-1"><div width="100%">
#
#
#
# <div>
#
#
#
#
#
#
#
#
#
# <p>👋 <strong>Good morning!</strong> Anybody running or attending the <a href="https://link.axios.com/click/27402572.226336/aHR0cHM6Ly93d3cuYmFhLm9yZy8_dXRtX3NvdXJjZT1uZXdzbGV0dGVyJnV0bV9tZWRpdW09ZW1haWwmdXRtX2NhbXBhaWduPW5ld3NsZXR0ZXJfYXhpb3NzcG9ydHMmc3RyZWFtPXRvcA/624d3914230d0217f00e46a0Bd80860b2">Boston Marathon</a> today? If so, send me photos to include tomorrow!</p><p><em>Today's word count: 1,730 words (7 minutes).</em></p><p>Let's sports...</p>
#
#
#
# &nbsp;
#
#
# &nbsp;
#
#
#
# <p><span>
# 1 big thing: ⚾️ The phenom
# </span>
#
#
#
#
# <img alt="Roki Sasaki" id="item00" width="600" src="https://proxy-prod.omnivore-image-cache.app/600x0,sw8ctlgooPBBFJv3KFbRQmuIz8pZqJBX00B-A99qJRD8/https://images.axios.com/5k5m451ltvX7kCef0Ek8eCsSr5I=/0x131:1929x1216/1920x1080/2022/04/18/1650281954632.jpg">
#
#
#
#
#
#
#
# <span>
# </span></p><p>Rōki Sasaki during his perfect game. Photo: Kyodo via Reuters</p>
# <p></p><p><strong>Rōki Sasaki,</strong> a 20-year-old Japanese pitching phenom, accomplished one of the greatest feats in sports history over the past week, tossing 17 straight perfect innings.</p><p><strong>Driving the news:</strong> Two Sundays ago, Sasaki threw the first perfect game in Nippon Professional Baseball (Japan's top league) since 1994. In his very next start this past Sunday, he threw eight more perfect innings.</p><ul><li><strong>Sasaki had a record 19 strikeouts</strong> (<a href="https://link.axios.com/click/27402572.226336/aHR0cHM6Ly93d3cueW91dHViZS5jb20vd2F0Y2g_dj1wdEVPaUh1TzIzdyZ1dG1fc291cmNlPW5ld3NsZXR0ZXImdXRtX21lZGl1bT1lbWFpbCZ1dG1fY2FtcGFpZ249bmV3c2xldHRlcl9heGlvc3Nwb3J0cyZzdHJlYW09dG9w/624d3914230d0217f00e46a0Bde0e58e3">including 13 straight</a>) during his perfect game, and he followed that up with <a href="https://link.axios.com/click/27402572.">14 more on Sunday</a> before being pulled in the eighth inning after 102 pitches.</li><li><strong>He hasn't allowed</strong> an opposing hitter to reach base in an NPB-record 52 straight plate appearances, which is six more than the MLB record (Yusmeiro Petit in 2014).</li></ul><p><strong>By the numbers:</strong> Sasaki's perfect game was the <a href="https://link.axios.com/click/27402572.">greatest pitching performance of all time</a>, according to the game score metric. The highest game score in MLB history was Kerry Wood's 105 in&nbsp;his 20-strikeout no-hitter in 1998. Sasaki's game score last Sunday? 106.</p><ul><li><strong>His fastball averaged</strong> <a href="https://link.axios.com/click/27402572.">better than 99.5 mph</a> and featured 19.7 inches of induced vertical break and 15.4 inches of horizontal break, per CBS.</li><li><strong>For reference,</strong> Yankees ace Gerrit Cole — who has arguably the best fastball in the majors — averaged 97.7 mph last year and featured 17.9 inches of induced vertical break and 11.9 inches of horizontal break.</li></ul><p><strong>The backdrop:</strong> Sasaki has been a superstar since high school and was courted by MLB scouts before opting to sign with his current team, the Chiba Lotte Marines.</p><ul><li><strong>He was the No. 1 pick</strong> in Japan's 2020 amateur draft and had a strong rookie season last year (3-2, 2.27 ERA). This year, he's on another level: 1.16 ERA, with 56 strikeouts against just seven hits and two walks.</li><li><strong>Yes, but:</strong> Sasaki's life <a href="https://link.axios.com/click/27402572.">hasn't been a bed of roses</a>. In 2011, his family's home was swept away&nbsp;in the Tōhoku tsunami, killing his father and grandparents.</li></ul><p><strong>The big picture:</strong> Japanese baseball stars are having a moment. Sasaki is suddenly a global sensation, Shohei Ohtani is the face of MLB, and Cubs rookie Seiya Suzuki is off to a ...
#
#
#
#
# <p><a href="https://link.axios.com/click/27402572.226336/aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3NoYXJlci5waHA_"></a>
# <a href="https://link.axios.com/click/27402572.226336/aHR0cHM6Ly90d2l0dGVyLmNvbS9pbnRlbnQvdHdlZXQ_..."></a>
# <a href="https://link.axios.com/click/27402572...."></a>
# <a href="mailto:?subject=From%20Axios:%201%20big%20thing:%20%E2%9A%BE%EF%B8%8F%20The%20phenom&amp;body=hongbow-s8n3htsxe%40inbox.omnivore.app%20has%20shared%20an%20Axios%20story%20with%20you%3A%0A%0A1%20big%20thing:%20%E2%9A%BE%EF%B8%8F%20The%20phenom%0Ahttps%3A%2F%2Fwww.axios.com%2Fnewsl
# <div class="page" id="readability-page-1"><div data-omnivore-anchor-idx="1">
# <td data-omnivore-anchor-idx="2">
# <!--[if mso]>
# <table style="width:600px;"><tr><td>
# <![endif]-->
# <div data-omnivore-anchor-idx="3">
# <tr data-omnivore-anchor-idx="4">
# <td data-omnivore-anchor-idx="5">&nbsp;</td>
# </tr>
# <tr data-omnivore-anchor-idx="6">
# <td data-omnivore-anchor-idx="7">
#
# </td>
# </tr>
# <tr data-omnivore-anchor-idx="8">
# <td data-omnivore-anchor-idx="9">&nbsp;</td>
# </tr>
# <tr data-omnivore-anchor-idx="10">
# <td data-omnivore-anchor-idx="11">
# <span data-omnivore-anchor-idx="12">Presented By SiriusXM</span>
# </td>
# </tr>
# <tr data-omnivore-anchor-idx="13">
# <td data-omnivore-anchor-idx="14">&nbsp;</td>
# </tr>
# <tr data-omnivore-anchor-idx="15">
# <td data-omnivore-anchor-idx="16">
# <span data-omnivore-anchor-idx="17">Axios Sports</span>
# </td>
# </tr>
# <tr data-omnivore-anchor-idx="18">
# <td data-omnivore-anchor-idx="19">
# <span data-omnivore-anchor-idx="20">By
# Jeff Tracy
# <span data-omnivore-anchor-idx="21">·</span>
# Feb 24, 2023
# </span>
# </td>
# </tr>
# <tr data-omnivore-anchor-idx="22">
# <td data-omnivore-anchor-idx="23">
# <p data-omnivore-anchor-idx="24">👋 <strong data-omnivore-anchor-idx="25">Happy Friday!</strong> Pacers center Myles Turner last night became the 47th player this season to score 40 points in a game, tied for the most in NBA history (2020-21). Who's gonna break the record?</p><p data-omnivore-anchor-idx="26"><em data-omnivore-anchor-idx="27">Today's word count: 1,916 words (7 minutes)</em></p><p data-omnivore-anchor-idx="28"><em data-omnivore-anchor-idx="29">Let's sports...</em></p>
# </td>
# </tr>
# <tr data-omnivore-anchor-idx="30">
# <td data-omnivore-anchor-idx="31">&nbsp;</td>
# </tr>
# <tr data-omnivore-anchor-idx="32">
# <td data-omnivore-anchor-idx="33">&nbsp;</td>
# </tr>
# <tr data-omnivore-anchor-idx="34">
# <td data-omnivore-anchor-idx="35">
# <span data-omnivore-anchor-idx="36">
# 1 big thing: ⚽️ MLS' high-tech gamble
# </span>
# </td>
# </tr>
# <tr data-omnivore-anchor-idx="37">
# <td data-omnivore-anchor-idx="38">
# <img data-omnivore-anchor-idx="39" data-omnivore-original-src="https://images.axios.com/tLlQuV-mnFXSUGXAwjQC3VkfIS4=/0x0:1920x1080/1920x1080/2023/02/23/1677159208921.jpg" src="https://proxy-prod.omnivore-image-cache.app/600x0,srX0A7-1VkwhODk4BiPHhkhCMuq0OZ3MDQ-wzJPgxGvE/https://images.axios.com/tLlQuV-mnFXSUGXAwjQC3VkfIS4=/0x0:1920x1080/1920x1080/2023/02/23/1677159208921.jpg" width="600" id="item00" alt="Illustration of Apple’s logo painted on turf. ">
# </td>
# </tr>
# <tr data-omnivore-anchor-idx="40">
# <td data-omnivore-anchor-idx="41"></td>
# </tr>
# <tr data-omnivore-anchor-idx="42">
# <td data-omnivore-anchor-idx="43">
# <span data-omnivore-anchor-idx="44">
# <p data-omnivore-anchor-idx="45">Illustration: Shoshana Gordon/Axios</p>
# </span>
# </td>
# </tr>
# <tr data-omnivore-anchor-idx="46">
# <td data-omnivore-anchor-idx="47">&nbsp;</td>
# </tr>
# <tr data-omnivore-anchor-idx="48">
# <td data-omnivore-anchor-idx="49">
# <p data-omnivore-anchor-idx="50"><strong data-omnivore-anchor-idx="51">With the MLS season kicking off tomorrow,</strong> the league's media gamble with Apple is about to take center stage, <em data-omnivore-anchor-idx="52">Axios' Tim Baysinger writes.</em></p><p data-omnivore-anchor-idx="53"><strong data-omnivore-anchor-idx="54">Why it matters:</strong> MLS' streaming deal with Apple is the first of its kind, and its success hinges on the league's ability to create a sports entertainment package that fans will pay for.</p><ul data-omnivore-anchor-idx="55"><li data-omnivore-anchor-idx="56"><strong data-omnivore-anchor-idx="57">"We're going to measure success</strong> by … how many people subscribe to MLS Season Pass," said MLS commissioner Don Garber, speaking to a room full of reporters Wednesday at the organization's new East Harlem studio.</li></ul><p data-omnivore-anchor-idx="58"><strong data-omnivore-anchor-idx="59">Details:</strong> The 10-year, $2.5 billion deal is a big leap for MLS and a vote of confidence in Apple, which remains a neophyte when it comes to airing live sports.</p><ul data-omnivore-anchor-idx="60"><li data-omnivore-anchor-idx="61"><strong data-omnivore-anchor-idx="62">Apple will begin streaming</strong> the matches on Saturday, the first day of the league's 28th season.</li></ul><p data-omnivore-anchor-idx="63"><strong data-omnivore-anchor-idx="64">Between the lines:</strong> MLS partnering with a tech platform that's relatively new to sports streaming means the league has an unprecedented level of control over its product.</p><ul data-omnivore-anchor-idx="65"><li data-omnivore-anchor-idx="66"><strong data-omnivore-anchor-idx="67">Apple will stream every match,</strong> but MLS will produce each segment on its own — the first time a pro sports league has gone all-in like this with a tech/streaming business.</li></ul><p data-omnivore-anchor-idx="68"><strong data-omnivore-anchor-idx="69">What they're saying: </strong>"There is no league domestically that is producing all of their games," said Garber, who hopes taking that risk yields a big return.</p><ul data-omnivore-anchor-idx="70"><li data-omnivore-anchor-idx="71"><strong data-omnivore-anchor-idx="72">"I love this expression,</strong> 'no pressure, no diamonds,'" he added. </li><li data-omnivore-anchor-idx="73"><strong data-omnivore-anchor-idx="74">"If you don't put yourself to task,</strong> then you're never going to be able to achieve the impossible."</li></ul><p data-omnivore-anchor-idx="75"><strong data-omnivore-anchor-idx="76">The big picture:</strong> If this landmark partnership is ultimately successful, it could become a blueprint for other leagues looking to replace the age-old RSN model, which is already wobbling.</p><ul data-omnivore-anchor-idx="77"><li data-omnivore-anchor-idx="78"><strong data-omnivore-anchor-idx="79">The potential bankruptcy</strong> of <a data-omnivore-anchor-idx="80" href="https://link.axios.com/click/30648466." target="_blank">Diamond Sports</a> — which owns rights to 42 teams across the NBA, MLB and NHL — could fast-track the kind of move MLS is doing with Apple.</li><li data-omnivore-anchor-idx="81"><strong data-omnivore-anchor-idx="82">In fact, </strong>both the NBA and MLB have already said they have plans to produce and distribute games themselves if Diamond's Bally Sports RSNs are unable.</li></ul>
# </td>
# </tr>
# <tr data-omnivore-anchor-idx="83">
# <td data-omnivore-anchor-idx="84">
# <a data-omnivore-anchor-idx="85" href="https://link.axios.com/click/30648466.207472/aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL3NoYXJlci5waHA_"></a>
# <a data-omnivore-anchor-idx="86" href="https://link.axios.com/click/30648466.207472/aHR0cHM6Ly90d2l0dGVyLmNvbS9pbnRlbnQvdHdlZXQ_..."></a>
# <a data-omnivore-anchor-idx="87" href="https://link.axios.com/click/30648466...."></a>
# <a data-omnivore-anchor-idx="88" href="mailto:?subject=From%20Axios:%201%20big%20thing:%20%E2%9A%BD%EF%B8%8F%20MLS'%20high-tech%20gamble&body=hongbow-s8n3htsxe%40inbox.omnivore.app%20has%20shared%20an%20Axios%20story%20with%20you%3A%0A%0A1%20big%20thing:%20%E2%9A%BD%EF%B8%8F%20MLS'%20high-tech%20gamble%0Ahttps%3A%2F%2Fwww.axios.com%2Fnewsletters%2Faxios-sports-23b4d872-3c1c-42f2-a60c-78656678f44f.html%3Fchunk%3D0%26utm_term%3Demshare#story0"></a>
# </td>
# </tr>
# <tr data-omnivore-anchor-idx="89">
# <td data-omnivore-anchor-idx="90">&nbsp;</td>
# </tr>
# <tr data-omnivore-anchor-idx="91">
# <td data-omnivore-anchor-idx="92">&nbsp;</td>
# </tr>
# <tr data-omnivore-anchor-idx="
# <div class="page" id="readability-page-1"><div width="100%">
#
#
#
# <div>
#
#
#
#
#
#
#
#
#
# <p><strong>Good Tuesday morning</strong>. <em>Smart Brevity™ count: 1,192 words ... 4½ mins. Edited by Justin Green.</em></p>
#
#
#
# &nbsp;
#
#
# &nbsp;
#
#
#
# <p><span>
# 1 big thing: Russia's digital back door
# </span>
#
#
#
#
# <img alt="" id="item00" width="600" src="https://proxy-prod.omnivore-image-cache.app/600x0,s5kBhWn-ZFo2bEBkRqCniN1DC8KnXFRoXDC6kXo6J1po/https://images.axios.com/pSZRqt0y4VY31yUjtORLCCK68BA=/0x0:1920x1080/1920x1080/2022/03/22/1647935448530.jpg">
#
#
#
#
#
#
#
# <span>
# </span></p><p>Illustration: Sarah Grillo/Axios</p>
# <p></p><p><strong>News outlets are finding creative ways</strong> to get around Kremlin efforts to block independent reporting inside Russia, <em>Axios' Sara Fischer writes. </em></p><ul><li><strong>Tech workarounds </strong>range from carbon-copy websites to encryption tools and anonymous browsers. </li></ul><p><strong>Why it matters: </strong>While old-school circumvention methods like <a href="https://link.axios.com/click/27106877.">short-wave radio</a> are being reintroduced, journalists trying to break through Russia's iron curtain for media are finding sophisticated digital techniques are more effective and efficient.</p><p><strong>The U.S. government-funded </strong>Radio Free Europe/Radio Liberty have been mirroring websites for news sites being censored — making exact copies of them at new internet addresses. </p><p><strong>Reality check: </strong>The Kremlin can block a mirrored domain once it's discovered, forcing news outlets to constantly shift to new domains. </p><ul><li><strong>Encrypted messaging channels, </strong>including Telegram or Whatsapp, are often used by outlets to communicate with their audiences to let them know which domains are active. </li></ul><p><strong>State of the art: </strong>News organizations are using encrypted channels to communicate with individual Russians on the ground who may provide photos and videos to Western outlets to verify and report on.</p><ul><li><strong>News sites and social networks </strong>are also beginning to establish their own Tor networks, which encrypt internet traffic and reroute it through thousands of servers around the world, making it virtually impossible to track. </li><li><strong>Twitter last week</strong> <a href="https://link.axios.com/click/27106877.555425/aHR0cHM6Ly90d2l0dGVyLmNvbS9BbGVjTXVmZmV0dC9zdGF0dXMvMTUwMTI4MjIyMzAwOTU0MjE1MT91dG1fc291cmNlPW5ld3NsZXR0ZXImdXRtX21lZGl1bT1lbWFpbCZ1dG1fY2FtcGFpZ249bmV3c2xldHRlcl9heGlvc2FtJnN0
# <a href="mailto:?subject=From%20Axios:%201%20big%20thing:%20Russia's%20digital%20back%20door&amp;body=hongbow-u5njgxzae%40inbox.omnivore.app%20has%20shared%20an%20Axios%20story%20with%20you%3A%0A%0A1%20big%20thing:%20Russia's%20digital%20back%20door%0Ahttps%3A%2F%2Fwww.axios.com%2Fnewsletters%2Faxios-am-9e7ec6e2-37a0-4843-8a77-14ac38637771.html%3Fchunk%3D0%26utm_term%3Demshare#story0"></a>
#
#
#
# &nbsp;
#
#
# &nbsp;
#
#
#
# <span>
# 2. ⚖️ Judge Jackson pledges independence
# </span></p><p><img width="100%" src="https://proxy-prod.omnivore-image-cache.app/0x0,sSO71Zedb7fr4hc5Mw5NUM4IRiRYH3qyGBObiXhyRxJU/https://images.axios.com/t4Z6jT0qLkG_U4ZGuYrPvqheLLg=/fit-in/1116x1300/2022/03/22/1647934402600.jpg" alt=""></p> <p>Photo: Kent Nishimura/L.A. Times via Getty Images</p><p><strong>Above, Judge Ketanji Brown Jackson </strong> — with her husband, Patrick Jackson, on her right — turns to their daughter, Leila Jackson. The folder holds the judge's 12-min. <a href="https://link.axios.com/click/27106877.">opening statement</a>, in which she said: </p><p>I decide cases from a neutral posture. I evaluate the facts, and I interpret and apply the law to the facts of the case before me, without fear or favor, consistent with my judicial oath.</p><p><img width="100%" src="https://proxy-prod.omnivore-image-cache.app/0x0,sJpQr_C1ID69BZl2GlrxlCn9hIyfNTL2bmW0ulfTFwbw/https://images.axios.com/bpdNLPjbzbIih_-4fuzWiE2fCQA=/fit-in/1116x1300/2022/03/22/1647934274879.jpg" alt=""></p> <p>What Judge Ketanji Brown Jackson sees. Photo: Jim Lo Scalzo/EPA/Pool via AP</p><p><strong>"Now, in preparing for these hearings,</strong> you may have read some of my more than 570 written decisions, and noticed that my opinions tend to be on the long side," she added. </p><ul><li><strong>"That is because</strong> I also believe in transparency: that people should know precisely what I think and the basis for my decision."</li></ul><p><strong>Senators begin</strong> questioning her at 9 a.m. ET today — the second of four days
# ['Title: 👑 Axios Sports: Still king.\n                Author: Kendall Baker.\n                Description: Binge on the stats & stories that drive the sports world, by sports editor Kendall Baker.\nDaily - Weekdays.\n                Reading progress: 0.\n                Content: None.',
#  'Title: 🔥 Axios Sports: Pickleball scoop.\n                Author: Kendall Baker.\n                Description: Binge on the stats & stories that drive the sports world, by sports editor Kendall Baker.\nDaily - Weekdays.\n                Reading progress: 0.\n                Content: None.',
#  'Title: Axios Sports.\n                Author: Kendall Baker.\n                Description: Binge on the stats & stories that drive the sports world, by sports editor Kendall Baker.\nDaily - Weekdays.\n                Reading progress: 0.\n                Content: None.',
#  "Title: ⚽️ Axios Sports: Streaming soccer.\n                Author: Jeff Tracy.\n                Description: 👋 Happy Friday! Pacers center Myles Turner last night became the 47th player this season to score 40 points in a game, tied for the most in NBA history (2020-21). Who's gonna break the record?.\n                Reading progress: 0.\n                Content: None.",
#  'Title: Axios Finish Line.\n                Author: Mike Allen.\n                Description: Start and end your work day with the stories that matter from Axios by Mike Allen, the world’s most-wired reporter. Then finish the night with what matters -- and lasts -- in life with insights from Mike, Jim VandeHei and Erica Pandey..\n                Reading progress: 0.\n                Content: None.']
