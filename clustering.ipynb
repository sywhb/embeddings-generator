# %% [markdown]
# # demo - clustering

# %%
# Install dependencies.
# !pip install top2vec
# !pip install tensorflow
# Out:
# Requirement already satisfied: top2vec in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (1.0.29)
# Requirement already satisfied: numpy>=1.20.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from top2vec) (1.22.4)
# Requirement already satisfied: pandas in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from top2vec) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.2.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from top2vec) (1.2.1)
# Requirement already satisfied: gensim>=4.0.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from top2vec) (4.3.1)
# Requirement already satisfied: umap-learn>=0.5.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from top2vec) (0.5.3)
# Requirement already satisfied: hdbscan>=0.8.27 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from top2vec) (0.8.33)
# Requirement already satisfied: wordcloud in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from top2vec) (1.9.2)
# Requirement already satisfied: scipy>=1.7.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from gensim>=4.0.0->top2vec) (1.10.0)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from gensim>=4.0.0->top2vec) (6.3.0)
# Requirement already satisfied: cython<3,>=0.27 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from hdbscan>=0.8.27->top2vec) (0.29.36)
# Requirement already satisfied: joblib>=1.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from hdbscan>=0.8.27->top2vec) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from scikit-learn>=1.2.0->top2vec) (3.1.0)
# Requirement already satisfied: numba>=0.49 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from umap-learn>=0.5.1->top2vec) (0.57.1)
# Requirement already satisfied: pynndescent>=0.5 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from umap-learn>=0.5.1->top2vec) (0.5.10)
# Requirement already satisfied: tqdm in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from umap-learn>=0.5.1->top2vec) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pandas->top2vec) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pandas->top2vec) (2022.1)
# Requirement already satisfied: pillow in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from wordcloud->top2vec) (9.4.0)
# Requirement already satisfied: matplotlib in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from wordcloud->top2vec) (3.6.3)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from numba>=0.49->umap-learn>=0.5.1->top2vec) (0.40.1)
# Requirement already satisfied: six>=1.5 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->top2vec) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib->wordcloud->top2vec) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib->wordcloud->top2vec) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib->wordcloud->top2vec) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib->wordcloud->top2vec) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib->wordcloud->top2vec) (23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from matplotlib->wordcloud->top2vec) (3.0.9)
# Collecting tensorflow
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/4e/d0/167c25cf115d6604adf11bb075a689dcb35bc5e351501e7dfdedef294498/tensorflow-2.13.0-cp310-cp310-macosx_12_0_arm64.whl.metadata
#   Downloading tensorflow-2.13.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (2.6 kB)
# Collecting tensorflow-macos==2.13.0 (from tensorflow)
#   Obtaining dependency information for tensorflow-macos==2.13.0 from https://files.pythonhosted.org/packages/77/29/b3a46ade07623f29d64cb43433aa1c6ba2bfe7419daee76f0cc9a6f7213a/tensorflow_macos-2.13.0-cp310-cp310-macosx_12_0_arm64.whl.metadata
#   Downloading tensorflow_macos-2.13.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (3.2 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (23.1.21)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (3.8.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (15.0.6.1)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.2.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (4.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.56.2)
# Collecting tensorboard<2.14,>=2.13 (from tensorflow-macos==2.13.0->tensorflow)
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 31.8 MB/s eta 0:00:0031m34.7 MB/s eta 0:00:01
# Collecting tensorflow-estimator<2.14,>=2.13.0 (from tensorflow-macos==2.13.0->tensorflow)
#   Obtaining dependency information for tensorflow-estimator<2.14,>=2.13.0 from https://files.pythonhosted.org/packages/72/5c/c318268d96791c6222ad7df1651bbd1b2409139afeb6f468c0f327177016/tensorflow_estimator-2.13.0-py2.py3-none-any.whl.metadata
#   Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.14,>=2.13.1 (from tensorflow-macos==2.13.0->tensorflow)
#   Obtaining dependency information for keras<2.14,>=2.13.1 from https://files.pythonhosted.org/packages/2e/f3/19da7511b45e80216cbbd9467137b2d28919c58ba1ccb971435cb631e470/keras-2.13.1-py3-none-any.whl.metadata
#   Downloading keras-2.13.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.16.0)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow)
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.28.2)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow)
#   Obtaining dependency information for tensorboard-data-server<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/da/61/6e9ff8258422d287eec718872fb71e05324356722ab658c8afda25f51539/tensorboard_data_server-0.7.1-py3-none-any.whl.metadata
#   Downloading tensorboard_data_server-0.7.1-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.2.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.2.2)
# Downloading tensorflow-2.13.0-cp310-cp310-macosx_12_0_arm64.whl (1.9 kB)
# Downloading tensorflow_macos-2.13.0-cp310-cp310-macosx_12_0_arm64.whl (189.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.3/189.3 MB 13.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading keras-2.13.1-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 38.4 MB/s eta 0:00:00m eta 0:00:01
# Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 23.3 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Installing collected packages: tensorflow-estimator, tensorboard-data-server, keras, google-auth-oauthlib, tensorboard, tensorflow-macos, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
#       Successfully uninstalled tensorflow-estimator-2.11.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.6.1
#     Uninstalling tensorboard-data-server-0.6.1:
#       Successfully uninstalled tensorboard-data-server-0.6.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 0.4.6
#     Uninstalling google-auth-oauthlib-0.4.6:
#       Successfully uninstalled google-auth-oauthlib-0.4.6
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
#   Attempting uninstall: tensorflow-macos
#     Found existing installation: tensorflow-macos 2.11.0
#     Uninstalling tensorflow-macos-2.11.0:
#       Successfully uninstalled tensorflow-macos-2.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.2.0 requires tensorflow-macos~=2.11.0, but you have tensorflow-macos 2.13.0 which is incompatible.
# tensorflowjs 4.2.0 requires packaging~=20.9, but you have packaging 23.0 which is incompatible.
# tensorflowjs 4.2.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.23.4 which is incompatible.
# Successfully installed google-auth-oauthlib-1.0.0 keras-2.13.1 tensorboard-2.13.0 tensorboard-data-server-0.7.1 tensorflow-2.13.0 tensorflow-estimator-2.13.0 tensorflow-macos-2.13.0

# %% [markdown]
# ## get data from elasticsearch

# %%
from elasticsearch import Elasticsearch
from elasticsearch.helpers import scan as escan
import pandas as pd
from collections import deque
import os

# Elasticsearch configuration
host = os.environ.get("ELASTICSEARCH_HOST")
username = os.environ.get("ELASTICSEARCH_USERNAME")
password = os.environ.get("ELASTICSEARCH_PASSWORD")
es = Elasticsearch([host], http_auth=(username, password))
index = 'pages_alias'


query = {
  "query": {
    "term": {
      "userId": {
        "value": os.environ.get("USER_ID")
      }
    }
  },
  "_source": {
    "includes": [
        "id",
        "title",
        "author",
        "description",
        "content",
        "readingProgressPercent"
    ]
  },
    "size": 1000
}
# Scan API for larger library
response = escan(client=es, index=index, query=query, request_timeout=30, size=1000)

# Initialize a double ended queue
output = deque()
# Extend deque with iterator
output.extend(response)
# Convert deque to DataFrame
# df = json_normalize(output)
# df = df[[x for x in df.columns if "_source." in x]]

# Search API
# search_result = es.search(index=index, body=query)
# hits = search_result["hits"]["hits"]
results = []
for hit in output:
    source = hit["_source"]
    source["id"] = hit["_id"]
    source["progress"] = source["readingProgressPercent"]
    # description could be null
    if 'description' not in source or source['description'] is None:
        source['description'] = ''
    # author could be null
    if 'author' not in source or source['author'] is None:
        source['author'] = ''
    results.append(source)
    
df = pd.DataFrame.from_records(results, exclude=['readingProgressPercent'])
df.head()
# Out:
#                    author                                        description  \
# 0              Mike Allen  Start and end your work day with the stories t...
# 1              Mike Allen  Start and end your work day with the stories t...
# 2              Mike Allen  Start and end your work day with the stories t...
# 3    Bloomberg's Big Take
# 4  The Pragmatic Engineer  Approaches for shipping code to production rel...
#
#                                      id                   title  \
# 0  dd1b02a2-a902-11ec-9d43-f3b9df394c94       Axios Finish Line
# 1  ea0ac5d0-a955-11ec-8f60-eb1aa2b42b51       Axios Finish Line
# 2  c48edf82-a9cb-11ec-94a3-e788a163c9be       Axios Finish Line
# 3  e090cb1a-a52e-11ec-821e-f7ca66bd6dc1            The Big Take
# 4                  jb609oABKc5BngQzn5dY  Shipping to Production
#
#                                              content  progress
# 0  <div class="page" id="readability-page-1"><div...       0.0
# 1  <div class="page" id="readability-page-1"><div...       0.0
# 2  <div class="page" id="readability-page-1"><div...       0.0
# 3  <div class="page" id="readability-page-1"><div...       0.0
# 4  <DIV class="page" id="readability-page-1"><div...       0.0

# %% [markdown]
# ## clustering

# %%
from top2vec import Top2Vec

documents = df['title'].to_list()
model = Top2Vec(documents, embedding_model='paraphrase-multilingual-MiniLM-L12-v2')
# Out:
# 2023-08-08 11:22:00,757 - top2vec - INFO - Pre-processing documents for training
# /Users/hongbowu/.pyenv/versions/3.10.4/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# 2023-08-08 11:22:00,921 - top2vec - INFO - Downloading paraphrase-multilingual-MiniLM-L12-v2 model
# 2023-08-08 11:22:02,867 - top2vec - INFO - Creating joint document/word embedding
# 2023-08-08 11:22:30,923 - top2vec - INFO - Creating lower dimension embedding of documents
# 2023-08-08 11:22:43,559 - top2vec - INFO - Finding dense areas of documents
# 2023-08-08 11:22:43,700 - top2vec - INFO - Finding topics

# %%
model.get_num_topics()
# Out:
# 89

# %%
model.get_topics(num_topics=10)
# Out:
# (array([['co', 'ev', 'dw', 'twitter', 'to', 'ie', 'oc', 'the', 'tl',
#          'and', 'pro', 'ai', 'in', 'on', 'of', 'ep', 'it', 'says', 'by',
#          'was', 'ars', 'but', 'this', 'what', 'or', 'an', 'its', 'do',
#          'com', 'that', 'my', 'things', 'man', 'for', 'you', 'more',
#          'dhbzoi', 'he', 'about', 'from', 'be', 'is', 'axios', 'as',
#          'know', 'his', 'at', 'biden', 'how', 'are'],
#         ['trump', 'politico', 'com', 'charged', 'he', 'news', 'us',
#          'twitter', 'his', 'latest', 'court', 'man', 'case', 'axios',
#          'now', 'no', 'says', 'huffpost', 'google', 'gop', 'co',
#          'against', 'today', 'articles', 'https', 'who', 'russia',
#          'stack', 'this', 'next', 'www', 'authentication', 'take', 'that',
#          'top', 'here', 'data', 'crypto', 'oc', 'five', 'by', 'was',
#          'thejournal', 'in', 'tl', 'search', 'amazon', 'do', 'musk',
#          'login'],
#         ['entertainment', 'com', 'twitter', 'youtube', 'co', 'on', 'news',
#          'huffpost', 'who', 'musk', 'axios', 'thejournal', 'people',
#          'game', 'by', 'ev', 'latest', 'politico', 'oc', 'off', 'he',
#          'my', 'his', 'dw', 'chat', 'at', 'biden', 'ie', 'out', 'ars',
#          'do', 'go', 'but', 'times', 'www', 'tl', 'dhbzoi', 'the', 'next',
#          'it', 'and', 'up', 'or', 'no', 'midway', 'with', 'top', 'in',
#          'ep', 'things'],
#         ['axios', 'ev', 'twitter', 'co', 'life', 'com', 'to', 'the',
#          'things', 'dw', 'by', 'on', 'ai', 'ie', 'but', 'what', 'pro',
#          'world', 'more', 'ep', 'you', 'and', 'be', 'ars', 'about',
#          'this', 'was', 'my', 'for', 'man', 'people', 'or', 'says',
#          'times', 'how', 'could', 'articles', 'dhbzoi', 'tl', 'in', 'why',
#          'it', 'review', 'live', 'an', 'of', 'politico', 'oc', 'from',
#          'next'],
#         ['sports', 'game', 'axios', 'entertainment', 'ars', 'against',
#          'twitter', 'ev', 'co', 'ai', 'best', 'oc', 'dublin', 'pro', 'my',
#          'musk', 'top', 'dw', 'ukraine', 'finish', 'russia', 'latest',
#          'politico', 'ie', 'can', 'dhbzoi', 'world', 'why', 'out', 'or',
#          'its', 'biden', 'year', 'but', 'off', 'week', 'what', 'and',
#          'man', 'on', 'it', 'all', 'years', 'most', 'things', 'do',
#          'times', 'the', 'in', 'review'],
#         ['twitter', 'com', 'tl', 'on', 'youtube', 'chat', 'co', 'www',
#          'ie', 'ev', 'he', 'dw', 'by', 'pro', 'my', 'his', 'man', 'ai',
#          'news', 'to', 'from', 'people', 'live', 'do', 'this', 'world',
#          'here', 'who', 'https', 'and', 'pm', 'oc', 'dublin', 'life',
#          'biden', 'more', 'most', 'for', 'that', 'says', 'in',
#          'thejournal', 'entertainment', 'of', 'times', 'login', 'at',
#          'or', 'things', 'know'],
#         ['game', 'entertainment', 'youtube', 'app', 'sports', 'latest',
#          'twitter', 'new', 'dhbzoi', 'things', 'world', 'dw', 'portal',
#          'vd', 'crypto', 'com', 'co', 'on', 'more', 'ai', 'ie', 'tl',
#          'pro', 'jb', 'technica', 'dublin', 'musk', 'review', 'ars',
#          'off', 'chat', 'against', 'tech', 'can', 'it', 'what', 'gop',
#          'ev', 'biden', 'in', 'year', 'times', 'one', 'at', 'thejournal',
#          'get', 'its', 'axios', 'oc', 'pm'],
#         ['politico', 'trump', 'com', 'twitter', 'us', 'news', 'co', 'now',
#          'says', 'no', 'against', 'who', 'but', 'today', 'latest', 'was',
#          'or', 'by', 'axios', 'could', 'have', 'the', 'this', 'biden',
#          'has', 'be', 'we', 'are', 'here', 'know', 'he', 'and', 'get',
#          'year', 'is', 'in', 'his', 'pro', 'cup', 'https', 'articles',
#          'up', 'can', 'not', 'thejournal', 'will', 'next', 'review', 'ev',
#          'ukraine'],
#         ['russia', 'ukraine', 'politico', 'musk', 'world', 'dhbzoi',
#          'against', 'dublin', 'twitter', 'huffpost', 'ireland', 'news',
#          'chat', 'cup', 'ev', 'latest', 'com', 'us', 'trump', 'game',
#          'ie', 'on', 'china', 'google', 'thejournal', 'axios', 'sports',
#          'ai', 'biden', 'the', 'jb', 'pro', 'co', 'of', 'ars', 'big',
#          'no', 'from', 'my', 'articles', 'to', 'oc', 'youtube', 'https',
#          'and', 'now', 'his', 'its', 'next', 'by'],
#         ['china', 'dhbzoi', 'russia', 'world', 'politico', 'musk', 'news',
#          'co', 'no', 'last', 'ev', 'but', 'most', 'axios', 'next',
#          'latest', 'says', 'will', 'the', 'articles', 'pm', 'us', 'an',
#          'years', 'what', 'is', 'know', 'gop', 'tl', 'people', 'twitter',
#          'about', 'not', 'more', 'against', 'dw', 'and', 'today', 'its',
#          'you', 'after', 'has', 'first', 'https', 'it', 'line', 'my',
#          'ars', 'times', 'year']], dtype='<U14'),
#  array([[0.9116335 , 0.904667  , 0.84193236, 0.83671427, 0.83227205,
#          0.8321624 , 0.7858509 , 0.78555197, 0.783766  , 0.77807766,
#          0.7730666 , 0.7718292 , 0.7713829 , 0.7628216 , 0.7622509 ,
#          0.7618295 , 0.756747  , 0.753983  , 0.74722373, 0.7461838 ,
#          0.7443157 , 0.7407402 , 0.7382963 , 0.7358744 , 0.7353964 ,
#          0.73460495, 0.73267484, 0.73085576, 0.7200593 , 0.71584666,
#          0.7112286 , 0.71028125, 0.7083194 , 0.706491  , 0.7020452 ,
#          0.6996364 , 0.6988738 , 0.69622034, 0.6956942 , 0.69404566,
#          0.69269896, 0.68825984, 0.6879866 , 0.68717974, 0.68666077,
#          0.68385744, 0.68265855, 0.6808234 , 0.67659765, 0.6763087 ],
#         [0.7050508 , 0.35815662, 0.24390592, 0.20968147, 0.20827286,
#          0.20619673, 0.19756085, 0.19096756, 0.16303696, 0.1568239 ,
#          0.14954954, 0.14165223, 0.13478045, 0.12650546, 0.12202639,
#          0.12028475, 0.11517823, 0.11338689, 0.11230765, 0.10658891,
#          0.10613953, 0.10603054, 0.10524639, 0.10463142, 0.09453402,
#          0.09189902, 0.09176293, 0.09153805, 0.09098125, 0.08948717,
#          0.08513606, 0.08379816, 0.08269025, 0.07983915, 0.07813874,
#          0.07612317, 0.07275377, 0.07030233, 0.06859557, 0.06723142,
